# %% [markdown]
# # 🧠 Alzheimer's Disease Classification

# %% [markdown]
# **We recommend the use of a GPU Accelerator to reduce the load on the CPU and to run the notebook faster.**

# %%
import tensorflow as tf
tf.config.experimental.set_memory_growth(tf.config.list_physical_devices('GPU')[0], True)
print(tf.__version__)
print ("Usage of gpu: {}".format(tf.config.list_physical_devices())) 
print ("Built with CUDA: {}".format(tf.test.is_built_with_cuda()))
# Out:
# Init Plugin
# 2.5.0Init Graph Optimizer
# Init Kernel
#
# Usage of gpu: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Built with CUDA: False

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
import tensorflow.keras
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, MaxPool2D

import pydot

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.5.0

# %% [markdown]
# ### Importing the necessary libraries

# %% [markdown]
# ### Data Pre-Processing

# %%
base_dir = "/Users/tarun/IIITN Project/ADNI/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['.DS_Store', 'Final MCI JPEG', 'Final EMCI JPEG', 'Final LMCI JPEG', 'Final AD JPEG', 'Final CN JPEG']

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'Final AD JPEG',
            'Final CN JPEG',
            'Final EMCI JPEG',
            'Final LMCI JPEG',
            'Final MCI JPEG']

IMG_SIZE = 256
IMAGE_SIZE = [256, 256]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Performing Image Augmentation to have more data samples

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 2614 images belonging to 5 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    labels =dict(zip([0,1,2,3,4], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 1296)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
#Retrieving the data from the ImageDataGenerator iterator

train_data, train_labels = train_data_gen.next()

# %%
#Getting to know the dimensions of our dataset

print(train_data.shape, train_labels.shape)
# Out:
# (2614, 256, 256, 3) (2614, 5)

# %%
#Performing over-sampling of the data, since the classes are imbalanced

sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (5800, 256, 256, 3) (5800, 5)

# %%
#Splitting the data into train, test, and validation sets

train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
print(train_data.shape, test_data.shape, train_labels.shape, test_labels.shape)
# Out:
# (3712, 256, 256, 3) (1160, 256, 256, 3) (3712, 5) (1160, 5)

# %% [markdown]
# ### Constructing a Convolutional Neural Network Architecture

# %%
def construct_model(act='relu'):
    """Constructing a Sequential CNN architecture for performing the classification task. """
    
    model = Sequential([
        Input(shape=(*IMAGE_SIZE, 3)),
        Conv2D(16, 3, activation=act, padding='same'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2), padding = 'valid'),
        BatchNormalization(),
        Conv2D(32, 3, activation=act, padding='same'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2), padding = 'valid'),
        BatchNormalization(),
        Conv2D(64, 3, activation=act, padding='same'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2), padding = 'valid'),
        BatchNormalization(),
        Conv2D(128, 3, activation=act, padding='same'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2), padding = 'valid'),
        BatchNormalization(),
        Dropout(0.2),
        Conv2D(256, 3, activation=act, padding='same'),
        Dropout(0.2),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.7),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(5, activation='softmax')        
    ], name = "cnn_model")

    return model

model = construct_model()
# Out:
# Metal device set to: Apple M1
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# 2022-01-29 18:01:52.507643: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-01-29 18:01:52.507783: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 16)      64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 34,022,757
# Trainable params: 34,022,277
# Non-trainable params: 480
# _________________________________________________________________

# %%
#Defining a custom callback function to stop training our model when accuracy goes above 99%

class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_acc') > 0.99:
            print("\nReached accuracy threshold! Terminating training.")
            self.model.stop_training = True
            
my_callback = MyCallback()

#EarlyStopping callback to make sure model is always learning
early_stopping = EarlyStopping(monitor='val_loss', patience=2)

# %%
#Defining other parameters for our CNN model



METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc'), 
           tfa.metrics.F1Score(num_classes=5)]

CALLBACKS = [my_callback]
    
model.compile(optimizer='adam',
              loss=tf.losses.CategoricalCrossentropy(),
              metrics=METRICS)

model.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 16)      64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 34,022,757
# Trainable params: 34,022,277
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# ### Training & Testing the Model

# %%
from sklearn.model_selection import KFold 
#Fit the training data to the model and validate it using the validation data
EPOCHS = 100

k = 20
kf = KFold(n_splits=k, random_state=None)
 
acc_score = []
 
for train_index , test_index in kf.split(train_data):
    X_train , X_test = train_data[train_index,:],train_data[test_index,:]
    y_train , y_test = train_labels[train_index] , train_labels[test_index]
    
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), callbacks=CALLBACKS, epochs=EPOCHS)
# Out:
# 2022-01-29 18:02:03.739310: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-01-29 18:02:03.739536: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/100
# 2022-01-29 18:02:04.231932: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - ETA: 0s - loss: 4.7259 - acc: 0.2007 - auc: 0.5059 - f1_score: 0.2007
# 2022-01-29 18:02:32.069257: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - 29s 255ms/step - loss: 4.7259 - acc: 0.2007 - auc: 0.5059 - f1_score: 0.2007 - val_loss: 1.6026 - val_acc: 0.2216 - val_auc: 0.5563 - val_f1_score: 0.0912
# Epoch 2/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.6818 - acc: 0.2212 - auc: 0.5174 - f1_score: 0.2185 - val_loss: 1.6100 - val_acc: 0.1892 - val_auc: 0.4858 - val_f1_score: 0.0888
# Epoch 3/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.6255 - acc: 0.2206 - auc: 0.5227 - f1_score: 0.2166 - val_loss: 1.6099 - val_acc: 0.1892 - val_auc: 0.4912 - val_f1_score: 0.0636
# Epoch 4/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.6257 - acc: 0.2172 - auc: 0.5195 - f1_score: 0.1937 - val_loss: 1.6100 - val_acc: 0.1892 - val_auc: 0.4880 - val_f1_score: 0.0636
# Epoch 5/100
# 111/111 [==============================] - 27s 248ms/step - loss: 1.6101 - acc: 0.2348 - auc: 0.5322 - f1_score: 0.1758 - val_loss: 1.6115 - val_acc: 0.1946 - val_auc: 0.4868 - val_f1_score: 0.0932
# Epoch 6/100
# 111/111 [==============================] - 27s 247ms/step - loss: 1.6093 - acc: 0.2271 - auc: 0.5368 - f1_score: 0.1739 - val_loss: 1.6096 - val_acc: 0.1946 - val_auc: 0.5065 - val_f1_score: 0.0954
# Epoch 7/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.6047 - acc: 0.2484 - auc: 0.5531 - f1_score: 0.2209 - val_loss: 1.6115 - val_acc: 0.1838 - val_auc: 0.4996 - val_f1_score: 0.0642
# Epoch 8/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.6032 - acc: 0.2430 - auc: 0.5404 - f1_score: 0.1840 - val_loss: 1.6149 - val_acc: 0.1838 - val_auc: 0.4840 - val_f1_score: 0.0969
# Epoch 9/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.6133 - acc: 0.2328 - auc: 0.5356 - f1_score: 0.1793 - val_loss: 1.5954 - val_acc: 0.2541 - val_auc: 0.5904 - val_f1_score: 0.1943
# Epoch 10/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.5936 - acc: 0.2549 - auc: 0.5536 - f1_score: 0.1998 - val_loss: 1.6084 - val_acc: 0.1622 - val_auc: 0.5199 - val_f1_score: 0.1476
# Epoch 11/100
# 111/111 [==============================] - 27s 248ms/step - loss: 1.5881 - acc: 0.2728 - auc: 0.5702 - f1_score: 0.2209 - val_loss: 1.5900 - val_acc: 0.2811 - val_auc: 0.5845 - val_f1_score: 0.1666
# Epoch 12/100
# 111/111 [==============================] - 27s 247ms/step - loss: 1.6048 - acc: 0.2294 - auc: 0.5337 - f1_score: 0.1380 - val_loss: 1.6007 - val_acc: 0.2324 - val_auc: 0.5745 - val_f1_score: 0.1356
# Epoch 13/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.5966 - acc: 0.2487 - auc: 0.5476 - f1_score: 0.1600 - val_loss: 1.6136 - val_acc: 0.2054 - val_auc: 0.5254 - val_f1_score: 0.1125
# Epoch 14/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.5848 - acc: 0.2628 - auc: 0.5757 - f1_score: 0.1968 - val_loss: 1.5847 - val_acc: 0.2811 - val_auc: 0.5989 - val_f1_score: 0.2444
# Epoch 15/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.5699 - acc: 0.2952 - auc: 0.5962 - f1_score: 0.2458 - val_loss: 1.5937 - val_acc: 0.2216 - val_auc: 0.5791 - val_f1_score: 0.1224
# Epoch 16/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.5769 - acc: 0.2849 - auc: 0.5943 - f1_score: 0.2390 - val_loss: 1.6035 - val_acc: 0.2162 - val_auc: 0.5557 - val_f1_score: 0.1208
# Epoch 17/100
# 111/111 [==============================] - 27s 248ms/step - loss: 1.5855 - acc: 0.2696 - auc: 0.5772 - f1_score: 0.2250 - val_loss: 1.5641 - val_acc: 0.2595 - val_auc: 0.6230 - val_f1_score: 0.2304
# Epoch 18/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.5543 - acc: 0.3025 - auc: 0.6145 - f1_score: 0.2655 - val_loss: 1.5374 - val_acc: 0.3189 - val_auc: 0.6364 - val_f1_score: 0.2568
# Epoch 19/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.5437 - acc: 0.3176 - auc: 0.6311 - f1_score: 0.2810 - val_loss: 1.5944 - val_acc: 0.2378 - val_auc: 0.5736 - val_f1_score: 0.1432
# Epoch 20/100
# 111/111 [==============================] - 27s 247ms/step - loss: 1.5168 - acc: 0.3374 - auc: 0.6496 - f1_score: 0.2962 - val_loss: 1.5050 - val_acc: 0.3730 - val_auc: 0.6910 - val_f1_score: 0.2875
# Epoch 21/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.5210 - acc: 0.3258 - auc: 0.6440 - f1_score: 0.2985 - val_loss: 1.5736 - val_acc: 0.2757 - val_auc: 0.6001 - val_f1_score: 0.1918
# Epoch 22/100
# 111/111 [==============================] - 27s 247ms/step - loss: 1.5006 - acc: 0.3448 - auc: 0.6628 - f1_score: 0.3122 - val_loss: 1.5105 - val_acc: 0.3405 - val_auc: 0.6644 - val_f1_score: 0.2676
# Epoch 23/100
# 111/111 [==============================] - 28s 250ms/step - loss: 1.4618 - acc: 0.3643 - auc: 0.6879 - f1_score: 0.3366 - val_loss: 1.3980 - val_acc: 0.4270 - val_auc: 0.7398 - val_f1_score: 0.3508
# Epoch 24/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.4235 - acc: 0.3796 - auc: 0.7093 - f1_score: 0.3526 - val_loss: 1.4177 - val_acc: 0.4324 - val_auc: 0.7430 - val_f1_score: 0.3068
# Epoch 25/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.3930 - acc: 0.4074 - auc: 0.7229 - f1_score: 0.3838 - val_loss: 1.3766 - val_acc: 0.4541 - val_auc: 0.7726 - val_f1_score: 0.3431
# Epoch 26/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.3366 - acc: 0.4358 - auc: 0.7580 - f1_score: 0.4133 - val_loss: 1.3240 - val_acc: 0.4811 - val_auc: 0.8033 - val_f1_score: 0.4051
# Epoch 27/100
# 111/111 [==============================] - 28s 249ms/step - loss: 1.2533 - acc: 0.4653 - auc: 0.7888 - f1_score: 0.4453 - val_loss: 1.3603 - val_acc: 0.4162 - val_auc: 0.7603 - val_f1_score: 0.3624
# Epoch 28/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.1997 - acc: 0.4936 - auc: 0.8076 - f1_score: 0.4782 - val_loss: 1.1771 - val_acc: 0.5838 - val_auc: 0.8509 - val_f1_score: 0.4990
# Epoch 29/100
# 111/111 [==============================] - 28s 248ms/step - loss: 1.1280 - acc: 0.5228 - auc: 0.8334 - f1_score: 0.5091 - val_loss: 1.1212 - val_acc: 0.6054 - val_auc: 0.8685 - val_f1_score: 0.5362
# Epoch 30/100
# 111/111 [==============================] - 28s 250ms/step - loss: 1.0339 - acc: 0.5495 - auc: 0.8602 - f1_score: 0.5380 - val_loss: 1.1218 - val_acc: 0.4703 - val_auc: 0.8207 - val_f1_score: 0.3872
# Epoch 31/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.9460 - acc: 0.5957 - auc: 0.8838 - f1_score: 0.5876 - val_loss: 1.2357 - val_acc: 0.4811 - val_auc: 0.7886 - val_f1_score: 0.4836
# Epoch 32/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.9119 - acc: 0.6161 - auc: 0.8939 - f1_score: 0.6094 - val_loss: 1.0423 - val_acc: 0.5622 - val_auc: 0.8694 - val_f1_score: 0.4724
# Epoch 33/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.8006 - acc: 0.6623 - auc: 0.9178 - f1_score: 0.6570 - val_loss: 0.8091 - val_acc: 0.7297 - val_auc: 0.9344 - val_f1_score: 0.6855
# Epoch 34/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.7452 - acc: 0.7012 - auc: 0.9303 - f1_score: 0.6972 - val_loss: 0.8865 - val_acc: 0.6486 - val_auc: 0.8990 - val_f1_score: 0.6056
# Epoch 35/100
# 111/111 [==============================] - 27s 248ms/step - loss: 0.6809 - acc: 0.7343 - auc: 0.9414 - f1_score: 0.7311 - val_loss: 0.6320 - val_acc: 0.7784 - val_auc: 0.9582 - val_f1_score: 0.7645
# Epoch 36/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.5832 - acc: 0.7723 - auc: 0.9564 - f1_score: 0.7692 - val_loss: 0.8835 - val_acc: 0.6378 - val_auc: 0.8973 - val_f1_score: 0.5951
# Epoch 37/100
# 111/111 [==============================] - 28s 250ms/step - loss: 0.5417 - acc: 0.7882 - auc: 0.9623 - f1_score: 0.7866 - val_loss: 0.7206 - val_acc: 0.7297 - val_auc: 0.9361 - val_f1_score: 0.7016
# Epoch 38/100
# 111/111 [==============================] - 28s 252ms/step - loss: 0.5096 - acc: 0.8032 - auc: 0.9662 - f1_score: 0.8014 - val_loss: 0.6480 - val_acc: 0.7730 - val_auc: 0.9543 - val_f1_score: 0.7615
# Epoch 39/100
# 111/111 [==============================] - 28s 251ms/step - loss: 0.4786 - acc: 0.8208 - auc: 0.9700 - f1_score: 0.8190 - val_loss: 0.5543 - val_acc: 0.8108 - val_auc: 0.9669 - val_f1_score: 0.7995
# Epoch 40/100
# 111/111 [==============================] - 27s 247ms/step - loss: 0.3872 - acc: 0.8568 - auc: 0.9797 - f1_score: 0.8559 - val_loss: 0.4791 - val_acc: 0.8595 - val_auc: 0.9758 - val_f1_score: 0.8483
# Epoch 41/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.3391 - acc: 0.8699 - auc: 0.9844 - f1_score: 0.8686 - val_loss: 0.5207 - val_acc: 0.8432 - val_auc: 0.9645 - val_f1_score: 0.8347
# Epoch 42/100
# 111/111 [==============================] - 28s 252ms/step - loss: 0.3267 - acc: 0.8829 - auc: 0.9853 - f1_score: 0.8818 - val_loss: 0.4291 - val_acc: 0.8541 - val_auc: 0.9798 - val_f1_score: 0.8397
# Epoch 43/100
# 111/111 [==============================] - 28s 252ms/step - loss: 0.2898 - acc: 0.8928 - auc: 0.9883 - f1_score: 0.8917 - val_loss: 0.4684 - val_acc: 0.8324 - val_auc: 0.9731 - val_f1_score: 0.8197
# Epoch 44/100
# 111/111 [==============================] - 28s 250ms/step - loss: 0.2503 - acc: 0.9093 - auc: 0.9908 - f1_score: 0.9087 - val_loss: 0.4625 - val_acc: 0.8486 - val_auc: 0.9730 - val_f1_score: 0.8391
# Epoch 45/100
# 111/111 [==============================] - 28s 252ms/step - loss: 0.2434 - acc: 0.9149 - auc: 0.9909 - f1_score: 0.9142 - val_loss: 0.5353 - val_acc: 0.8216 - val_auc: 0.9637 - val_f1_score: 0.8108
# Epoch 46/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.2390 - acc: 0.9138 - auc: 0.9910 - f1_score: 0.9131 - val_loss: 0.4566 - val_acc: 0.8486 - val_auc: 0.9742 - val_f1_score: 0.8401
# Epoch 47/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.2183 - acc: 0.9220 - auc: 0.9930 - f1_score: 0.9211 - val_loss: 0.4083 - val_acc: 0.8595 - val_auc: 0.9789 - val_f1_score: 0.8497
# Epoch 48/100
# 111/111 [==============================] - 28s 255ms/step - loss: 0.1929 - acc: 0.9345 - auc: 0.9939 - f1_score: 0.9340 - val_loss: 0.4267 - val_acc: 0.8324 - val_auc: 0.9770 - val_f1_score: 0.8192
# Epoch 49/100
# 111/111 [==============================] - 27s 247ms/step - loss: 0.2012 - acc: 0.9388 - auc: 0.9929 - f1_score: 0.9382 - val_loss: 0.6760 - val_acc: 0.7514 - val_auc: 0.9437 - val_f1_score: 0.7571
# Epoch 50/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1802 - acc: 0.9390 - auc: 0.9946 - f1_score: 0.9385 - val_loss: 0.4340 - val_acc: 0.8162 - val_auc: 0.9758 - val_f1_score: 0.7979
# Epoch 51/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1668 - acc: 0.9470 - auc: 0.9948 - f1_score: 0.9464 - val_loss: 0.3975 - val_acc: 0.8595 - val_auc: 0.9804 - val_f1_score: 0.8490
# Epoch 52/100
# 111/111 [==============================] - 27s 248ms/step - loss: 0.1355 - acc: 0.9498 - auc: 0.9966 - f1_score: 0.9493 - val_loss: 0.3319 - val_acc: 0.8865 - val_auc: 0.9844 - val_f1_score: 0.8815
# Epoch 53/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1332 - acc: 0.9572 - auc: 0.9959 - f1_score: 0.9568 - val_loss: 0.3838 - val_acc: 0.8973 - val_auc: 0.9788 - val_f1_score: 0.8900
# Epoch 54/100
# 111/111 [==============================] - 27s 248ms/step - loss: 0.1409 - acc: 0.9541 - auc: 0.9962 - f1_score: 0.9536 - val_loss: 0.3278 - val_acc: 0.9081 - val_auc: 0.9863 - val_f1_score: 0.9027
# Epoch 55/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1200 - acc: 0.9654 - auc: 0.9963 - f1_score: 0.9651 - val_loss: 0.3576 - val_acc: 0.8703 - val_auc: 0.9841 - val_f1_score: 0.8641
# Epoch 56/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1041 - acc: 0.9708 - auc: 0.9977 - f1_score: 0.9705 - val_loss: 0.3799 - val_acc: 0.8595 - val_auc: 0.9800 - val_f1_score: 0.8508
# Epoch 57/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1017 - acc: 0.9682 - auc: 0.9976 - f1_score: 0.9680 - val_loss: 0.3598 - val_acc: 0.8595 - val_auc: 0.9820 - val_f1_score: 0.8515
# Epoch 58/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1074 - acc: 0.9631 - auc: 0.9974 - f1_score: 0.9628 - val_loss: 0.3218 - val_acc: 0.9189 - val_auc: 0.9848 - val_f1_score: 0.9151
# Epoch 59/100
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0913 - acc: 0.9716 - auc: 0.9979 - f1_score: 0.9714 - val_loss: 0.4548 - val_acc: 0.8757 - val_auc: 0.9733 - val_f1_score: 0.8657
# Epoch 60/100
# 111/111 [==============================] - 27s 247ms/step - loss: 0.1031 - acc: 0.9691 - auc: 0.9969 - f1_score: 0.9688 - val_loss: 0.3253 - val_acc: 0.9243 - val_auc: 0.9849 - val_f1_score: 0.9214
# Epoch 61/100
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0988 - acc: 0.9714 - auc: 0.9977 - f1_score: 0.9711 - val_loss: 0.3346 - val_acc: 0.9081 - val_auc: 0.9831 - val_f1_score: 0.9014
# Epoch 62/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.1047 - acc: 0.9680 - auc: 0.9970 - f1_score: 0.9676 - val_loss: 0.3426 - val_acc: 0.8865 - val_auc: 0.9827 - val_f1_score: 0.8792
# Epoch 63/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0842 - acc: 0.9773 - auc: 0.9976 - f1_score: 0.9771 - val_loss: 0.4243 - val_acc: 0.8649 - val_auc: 0.9791 - val_f1_score: 0.8563
# Epoch 64/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0708 - acc: 0.9770 - auc: 0.9981 - f1_score: 0.9768 - val_loss: 0.2848 - val_acc: 0.9351 - val_auc: 0.9863 - val_f1_score: 0.9336
# Epoch 65/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0573 - acc: 0.9810 - auc: 0.9990 - f1_score: 0.9808 - val_loss: 0.3976 - val_acc: 0.9081 - val_auc: 0.9806 - val_f1_score: 0.9043
# Epoch 66/100
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0686 - acc: 0.9807 - auc: 0.9981 - f1_score: 0.9805 - val_loss: 0.3099 - val_acc: 0.9027 - val_auc: 0.9824 - val_f1_score: 0.8976
# Epoch 67/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0836 - acc: 0.9739 - auc: 0.9977 - f1_score: 0.9736 - val_loss: 0.3429 - val_acc: 0.8865 - val_auc: 0.9858 - val_f1_score: 0.8767
# Epoch 68/100
# 111/111 [==============================] - 28s 255ms/step - loss: 0.0965 - acc: 0.9691 - auc: 0.9976 - f1_score: 0.9688 - val_loss: 0.3764 - val_acc: 0.8865 - val_auc: 0.9833 - val_f1_score: 0.8795
# Epoch 69/100
# 111/111 [==============================] - 28s 251ms/step - loss: 0.0752 - acc: 0.9770 - auc: 0.9982 - f1_score: 0.9768 - val_loss: 0.4102 - val_acc: 0.8973 - val_auc: 0.9778 - val_f1_score: 0.8908
# Epoch 70/100
# 111/111 [==============================] - 28s 250ms/step - loss: 0.0531 - acc: 0.9838 - auc: 0.9989 - f1_score: 0.9837 - val_loss: 0.3679 - val_acc: 0.8973 - val_auc: 0.9810 - val_f1_score: 0.8892
# Epoch 71/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0604 - acc: 0.9816 - auc: 0.9984 - f1_score: 0.9814 - val_loss: 0.4670 - val_acc: 0.8919 - val_auc: 0.9768 - val_f1_score: 0.8858
# Epoch 72/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0695 - acc: 0.9804 - auc: 0.9976 - f1_score: 0.9803 - val_loss: 0.5049 - val_acc: 0.8649 - val_auc: 0.9719 - val_f1_score: 0.8577
# Epoch 73/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0581 - acc: 0.9821 - auc: 0.9985 - f1_score: 0.9820 - val_loss: 0.4247 - val_acc: 0.9081 - val_auc: 0.9781 - val_f1_score: 0.9054
# Epoch 74/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0846 - acc: 0.9782 - auc: 0.9976 - f1_score: 0.9780 - val_loss: 0.3833 - val_acc: 0.9189 - val_auc: 0.9825 - val_f1_score: 0.9156
# Epoch 75/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0487 - acc: 0.9864 - auc: 0.9985 - f1_score: 0.9863 - val_loss: 0.3835 - val_acc: 0.9189 - val_auc: 0.9797 - val_f1_score: 0.9151
# Epoch 76/100
# 111/111 [==============================] - 28s 251ms/step - loss: 0.0589 - acc: 0.9810 - auc: 0.9986 - f1_score: 0.9808 - val_loss: 0.3985 - val_acc: 0.8865 - val_auc: 0.9793 - val_f1_score: 0.8821
# Epoch 77/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0746 - acc: 0.9841 - auc: 0.9982 - f1_score: 0.9840 - val_loss: 0.5621 - val_acc: 0.8486 - val_auc: 0.9672 - val_f1_score: 0.8397
# Epoch 78/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0703 - acc: 0.9830 - auc: 0.9974 - f1_score: 0.9829 - val_loss: 0.3788 - val_acc: 0.8919 - val_auc: 0.9829 - val_f1_score: 0.8830
# Epoch 79/100
# 111/111 [==============================] - 27s 248ms/step - loss: 0.0604 - acc: 0.9819 - auc: 0.9991 - f1_score: 0.9817 - val_loss: 0.3376 - val_acc: 0.9135 - val_auc: 0.9847 - val_f1_score: 0.9071
# Epoch 80/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0395 - acc: 0.9870 - auc: 0.9993 - f1_score: 0.9868 - val_loss: 0.3674 - val_acc: 0.9081 - val_auc: 0.9780 - val_f1_score: 0.9019
# Epoch 81/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0684 - acc: 0.9782 - auc: 0.9980 - f1_score: 0.9779 - val_loss: 0.3680 - val_acc: 0.8973 - val_auc: 0.9823 - val_f1_score: 0.8910
# Epoch 82/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0556 - acc: 0.9819 - auc: 0.9987 - f1_score: 0.9817 - val_loss: 0.5573 - val_acc: 0.8486 - val_auc: 0.9657 - val_f1_score: 0.8423
# Epoch 83/100
# 111/111 [==============================] - 28s 250ms/step - loss: 0.0741 - acc: 0.9804 - auc: 0.9976 - f1_score: 0.9802 - val_loss: 0.9863 - val_acc: 0.7622 - val_auc: 0.9258 - val_f1_score: 0.7611
# Epoch 84/100
# 111/111 [==============================] - 28s 250ms/step - loss: 0.0713 - acc: 0.9827 - auc: 0.9978 - f1_score: 0.9825 - val_loss: 0.3546 - val_acc: 0.9135 - val_auc: 0.9838 - val_f1_score: 0.9064
# Epoch 85/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0443 - acc: 0.9884 - auc: 0.9987 - f1_score: 0.9883 - val_loss: 0.3334 - val_acc: 0.9189 - val_auc: 0.9827 - val_f1_score: 0.9163
# Epoch 86/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0429 - acc: 0.9858 - auc: 0.9991 - f1_score: 0.9857 - val_loss: 0.4423 - val_acc: 0.8865 - val_auc: 0.9771 - val_f1_score: 0.8778
# Epoch 87/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0425 - acc: 0.9898 - auc: 0.9991 - f1_score: 0.9897 - val_loss: 0.3316 - val_acc: 0.9189 - val_auc: 0.9870 - val_f1_score: 0.9159
# Epoch 88/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0343 - acc: 0.9895 - auc: 0.9994 - f1_score: 0.9894 - val_loss: 0.3961 - val_acc: 0.9027 - val_auc: 0.9809 - val_f1_score: 0.8964
# Epoch 89/100
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0392 - acc: 0.9904 - auc: 0.9988 - f1_score: 0.9903 - val_loss: 0.3925 - val_acc: 0.9081 - val_auc: 0.9809 - val_f1_score: 0.9041
# Epoch 90/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0700 - acc: 0.9796 - auc: 0.9978 - f1_score: 0.9795 - val_loss: 0.4060 - val_acc: 0.9243 - val_auc: 0.9799 - val_f1_score: 0.9219
# Epoch 91/100
# 111/111 [==============================] - 28s 252ms/step - loss: 0.0396 - acc: 0.9878 - auc: 0.9990 - f1_score: 0.9877 - val_loss: 0.4084 - val_acc: 0.9459 - val_auc: 0.9824 - val_f1_score: 0.9435
# Epoch 92/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0676 - acc: 0.9816 - auc: 0.9980 - f1_score: 0.9814 - val_loss: 0.4498 - val_acc: 0.8919 - val_auc: 0.9796 - val_f1_score: 0.8854
# Epoch 93/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0342 - acc: 0.9898 - auc: 0.9993 - f1_score: 0.9897 - val_loss: 0.3778 - val_acc: 0.9027 - val_auc: 0.9827 - val_f1_score: 0.8975
# Epoch 94/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0444 - acc: 0.9898 - auc: 0.9986 - f1_score: 0.9897 - val_loss: 0.3538 - val_acc: 0.8973 - val_auc: 0.9834 - val_f1_score: 0.8890
# Epoch 95/100
# 111/111 [==============================] - 28s 250ms/step - loss: 0.0417 - acc: 0.9887 - auc: 0.9988 - f1_score: 0.9886 - val_loss: 0.3831 - val_acc: 0.9027 - val_auc: 0.9794 - val_f1_score: 0.8947
# Epoch 96/100
# 111/111 [==============================] - 28s 250ms/step - loss: 0.0265 - acc: 0.9929 - auc: 0.9995 - f1_score: 0.9929 - val_loss: 0.3147 - val_acc: 0.9189 - val_auc: 0.9830 - val_f1_score: 0.9147
# Epoch 97/100
# 111/111 [==============================] - 28s 253ms/step - loss: 0.0298 - acc: 0.9921 - auc: 0.9992 - f1_score: 0.9920 - val_loss: 0.3530 - val_acc: 0.9243 - val_auc: 0.9789 - val_f1_score: 0.9207
# Epoch 98/100
# 111/111 [==============================] - 28s 252ms/step - loss: 0.0500 - acc: 0.9906 - auc: 0.9982 - f1_score: 0.9906 - val_loss: 0.5559 - val_acc: 0.8378 - val_auc: 0.9616 - val_f1_score: 0.8320
# Epoch 99/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0420 - acc: 0.9881 - auc: 0.9991 - f1_score: 0.9880 - val_loss: 0.4216 - val_acc: 0.8811 - val_auc: 0.9800 - val_f1_score: 0.8749
# Epoch 100/100
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0452 - acc: 0.9881 - auc: 0.9988 - f1_score: 0.9880 - val_loss: 0.3868 - val_acc: 0.9081 - val_auc: 0.9804 - val_f1_score: 0.9012

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
train_scores = model.evaluate(X_train,y_train)
val_scores = model.evaluate(X_test,y_test)


print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
# Out:
# 111/111 [==============================] - 12s 105ms/step - loss: 0.0031 - acc: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# 6/6 [==============================] - 1s 118ms/step - loss: 0.3868 - acc: 0.9081 - auc: 0.9804 - f1_score: 0.9012
# Training Accuracy: 100.00%
# Validation Accuracy: 90.81%

# %%
#Predicting the test data

pred_labels = model.predict(test_data)
# Out:
# 2022-01-29 18:48:21.663512: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                  precision    recall  f1-score   support
#
#   Final AD JPEG       0.94      0.92      0.93       225
#   Final CN JPEG       0.73      0.82      0.77       241
# Final EMCI JPEG       0.87      0.92      0.89       230
# Final LMCI JPEG       0.98      0.98      0.98       224
#  Final MCI JPEG       0.96      0.80      0.87       240
#
#       micro avg       0.89      0.89      0.89      1160
#       macro avg       0.90      0.89      0.89      1160
#    weighted avg       0.89      0.89      0.89      1160
#     samples avg       0.89      0.89      0.89      1160

# %%
#Plot the confusion matrix to understand the classification in detail

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels=CLASSES, yticklabels=CLASSES)

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
#Printing some other classification metrics

print("Balanced Accuracy Score: {} %".format(round(BAS(test_ls, pred_ls) * 100, 2)))
print("Matthew's Correlation Coefficient: {} %".format(round(MCC(test_ls, pred_ls) * 100, 2)))
# Out:
# Balanced Accuracy Score: 88.91 %
# Matthew's Correlation Coefficient: 85.98 %

# %%
#Saving the model for future use

model_dir = work_dir + "alzheimer_cnn_model"
model.save(model_dir, save_format='h5')
os.listdir(work_dir)
# Out:
# ['.DS_Store',
#  'Final MCI JPEG',
#  'alzheimer_cnn_model',
#  'Final EMCI JPEG',
#  'Final LMCI JPEG',
#  'Final AD JPEG',
#  'Final CN JPEG']

# %%
pretrained_model = tf.keras.models.load_model(model_dir)

#Check its architecture
plot_model(pretrained_model, to_file=work_dir + "model_plot.png", show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8k/fywv4p6j14741dmv12zpcyvh0000gn/T/ipykernel_98592/2207876520.py in <module>
#       2
#       3 #Check its architecture
# ----> 4 plot_model(pretrained_model, to_file=work_dir + "model_plot.png", show_shapes=True, show_layer_names=True)
#
# NameError: name 'plot_model' is not defined

# %% [markdown]
# ### Using the InceptionV3 model as a base model for the task

# %% [markdown]
# **Please check out the notebook here:
# [Inception V3 Model Notebook](https://www.kaggle.com/vishakansubramanian/alzheimer-s-disease-classification-inceptionv3)**
